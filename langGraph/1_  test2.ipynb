# %%
# !pip install dotenv
# Out:
# WARNING: Ignoring invalid distribution -umpy (/Users/ankushchoudhari76/Documents/VS CODE/.venv/lib/python3.9/site-packages)
# Collecting dotenv
#   Using cached dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Requirement already satisfied: python-dotenv in /Users/ankushchoudhari76/Documents/VS CODE/.venv/lib/python3.9/site-packages (from dotenv) (1.1.0)
# Using cached dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# WARNING: Error parsing dependencies of opencv-python-headless: [Errno 2] No such file or directory: '/Users/ankushchoudhari76/Documents/VS CODE/.venv/lib/python3.9/site-packages/opencv_python_headless-4.12.0.88.dist-info/METADATA'
# WARNING: Ignoring invalid distribution -umpy (/Users/ankushchoudhari76/Documents/VS CODE/.venv/lib/python3.9/site-packages)
# Installing collected packages: dotenv
# WARNING: Ignoring invalid distribution -umpy (/Users/ankushchoudhari76/Documents/VS CODE/.venv/lib/python3.9/site-packages)
# Successfully installed dotenv-0.9.9
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from langgraph.graph import StateGraph,START ,END
from langchain_openai import ChatOpenAI 
from typing  import TypedDict
import os
from dotenv import load_dotenv
# Out:
# /Users/ankushchoudhari76/Documents/VS CODE/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    model="meta-llama/llama-3.3-70b-instruct:free"
)

# %%
# create  a state 
class LLMState(TypedDict):
    question : str 
    answer : str

# %%
def llm_qa(state: LLMState)->LLMState:

    # extract the question from state 

    question = state['question']

    #form a prompt 
    prompt = f'Answer the following question{question}'

    # ask the que to the LLm 

    answer = llm.invoke(prompt).content

    #update the answer in the state 

    state['answer']= answer 

    return state

# %%
# create  our  graph 

graph = StateGraph(LLMState)

# add node 

graph.add_node('llm_qa' , llm_qa)

# add edge 

graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa',END)

#compile 

workflow = graph.compile()

# %%
# execute 
intial_state = {'question' : 'capital of india ?' }

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'question': 'capital of india ?', 'answer': 'New Delhi'}
